# %%
import ast, json
import pandas as pd

# Load CSV summary
summary = pd.read_csv("outputs/recon_summary.csv")
summary["columns_different"] = summary["columns_different"].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) and x.startswith("[") else x
)
display(summary.sort_values(["priority","cash_impact"], ascending=[False, False]).head(50))

# Load JSONL details
records = [json.loads(line) for line in open("outputs/recon_details.jsonl","r",encoding="utf-8")]
detail_df = pd.json_normalize(records)
display(detail_df)
# Out:
#    event_key                    columns_different  cash_impact  \
# 0  960789012  [net_qc, net_sc, tax_amt, tax_rate]     450050.0
# 1  970456789                            [nominal]      15000.0
# 2  970456789  [gross_qc, net_qc, net_sc, tax_amt]       6200.0
# 3  950123456                                   []          0.0
# 4  970456789                                   []          0.0
#
#                  reason_code  priority  \
# 0        NET_AMOUNT_MISMATCH         3
# 1  NOMINAL_POSITION_MISMATCH         3
# 2          GROSS_QC_MISMATCH         3
# 3                      MATCH         1
# 4                      MATCH         1
#
#                                          explanation  \
# 0  The net amounts differ between the two sources...
# 1  The nominal position differs between the two s...
# 2  The gross quantity in the custody record diffe...
# 3  All provided fields match between the two sour...
# 4  All values match between the two sources, indi...
#
#                                        suggested_fix
# 0  Review the net amounts and tax details to ensu...
# 1  Verify the nominal position with the relevant ...
# 2  Review the gross quantity calculations and ens...
# 3        No action required as there is no mismatch.
# 4     No action is required as there is no mismatch.
#    payload.event_key payload.isin_nb payload.isin_cu  \
# 0          950123456    US0378331005    US0378331005
# 1          960789012    KR7005930003    KR7005930003
# 2          970456789    CH0038863350    CH0038863350
# 3          970456789    CH0038863350    CH0038863350
# 4          970456789    CH0038863350    CH0038863350
#
#           payload.ex_date_nb         payload.ex_date_cu  \
# 0  2025-02-07 00:00:00+00:00  2025-02-07 00:00:00+00:00
# 1  2025-03-31 00:00:00+00:00  2025-03-31 00:00:00+00:00
# 2  2025-04-25 00:00:00+00:00  2025-04-25 00:00:00+00:00
# 3  2025-04-25 00:00:00+00:00  2025-04-25 00:00:00+00:00
# 4  2025-04-25 00:00:00+00:00  2025-04-25 00:00:00+00:00
#
#          payload.pay_date_nb        payload.pay_date_cu payload.qc_nb  \
# 0  2025-02-14 00:00:00+00:00  2025-02-14 00:00:00+00:00           USD
# 1  2025-05-20 00:00:00+00:00  2025-05-20 00:00:00+00:00           KRW
# 2  2025-04-29 00:00:00+00:00  2025-04-29 00:00:00+00:00           CHF
# 3  2025-04-29 00:00:00+00:00  2025-04-29 00:00:00+00:00           CHF
# 4  2025-04-29 00:00:00+00:00  2025-04-29 00:00:00+00:00           CHF
#
#   payload.qc_cu payload.sc_nb  ... payload.diffs.nominal_diff  \
# 0           USD           USD  ...                        0.0
# 1           KRW           USD  ...                        0.0
# 2           CHF           CHF  ...                        0.0
# 3           CHF           CHF  ...                    15000.0
# 4           CHF           CHF  ...                        0.0
#
#    payload.diffs.div_ps_diff             payload.different_fields  \
# 0                        0.0                                   []
# 1                        0.0  [net_qc, net_sc, tax_amt, tax_rate]
# 2                        0.0                                   []
# 3                        0.0                            [nominal]
# 4                        0.0  [gross_qc, net_qc, net_sc, tax_amt]
#
#    payload.cash_impact  classification.reason_code  \
# 0                  0.0                       MATCH
# 1             450050.0         NET_AMOUNT_MISMATCH
# 2                  0.0                       MATCH
# 3              15000.0   NOMINAL_POSITION_MISMATCH
# 4               6200.0           GROSS_QC_MISMATCH
#
#                           classification.explanation  \
# 0  All provided fields match between the two sour...
# 1  The net amounts differ between the two sources...
# 2  All values match between the two sources, indi...
# 3  The nominal position differs between the two s...
# 4  The gross quantity in the custody record diffe...
#
#                         classification.suggested_fix  classification.priority  \
# 0        No action required as there is no mismatch.                        1
# 1  Review the net amounts and tax details to ensu...                        3
# 2     No action is required as there is no mismatch.                        1
# 3  Verify the nominal position with the relevant ...                        3
# 4  Review the gross quantity calculations and ens...                        3
#
#         classification.evidence_fields  classification.notes
# 0                                   []
# 1  [net_qc, net_sc, tax_amt, tax_rate]
# 2                                   []
# 3                            [nominal]
# 4  [gross_qc, net_qc, net_sc, tax_amt]
#
# [5 rows x 43 columns]
