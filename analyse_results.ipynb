# %%
import ast, json
import pandas as pd



# load CSV summary
summary = pd.read_csv("outputs/recon_summary.csv")
summary["columns_different"] = summary["columns_different"].apply(
    lambda x: ast.literal_eval(x) if isinstance(x, str) and x.startswith("[") else x
)
display(summary.sort_values(["priority","cash_impact"], ascending=[False, False]).head(50))

# load JSONL details
records = [json.loads(line) for line in open("outputs/recon_details.jsonl","r",encoding="utf-8")]
detail_df = pd.json_normalize(records)
display(detail_df)
# Out:
#    event_key    account       isin_nb       isin_cu  \
# 0  960789012  712345678  KR7005930003  KR7005930003
# 1  970456789  823456790  CH0038863350  CH0038863350
# 2  970456789  823456791  CH0038863350  CH0038863350
#
#                      columns_different  cash_impact  \
# 0  [net_qc, net_sc, tax_amt, tax_rate]     450050.0
# 1                            [nominal]      15000.0
# 2  [gross_qc, net_qc, net_sc, tax_amt]       6200.0
#
#                  reason_code  priority  \
# 0        NET_AMOUNT_MISMATCH         3
# 1  NOMINAL_POSITION_MISMATCH         3
# 2          GROSS_QC_MISMATCH         3
#
#                                          explanation  \
# 0  The net amounts in the custody and NBIM record...
# 1  The nominal position differs between the two a...
# 2  The gross amount in the custody record differs...
#
#                                        suggested_fix
# 0  Review the net amounts reported in both system...
# 1  Review the nominal position entries for both a...
# 2  Investigate the source of the gross amount dis...
#    payload.event_key payload.account payload.isin_nb payload.isin_cu  \
# 0          960789012       712345678    KR7005930003    KR7005930003
# 1          970456789       823456790    CH0038863350    CH0038863350
# 2          970456789       823456791    CH0038863350    CH0038863350
#
#           payload.ex_date_nb         payload.ex_date_cu  \
# 0  2025-03-31 00:00:00+00:00  2025-03-31 00:00:00+00:00
# 1  2025-04-25 00:00:00+00:00  2025-04-25 00:00:00+00:00
# 2  2025-04-25 00:00:00+00:00  2025-04-25 00:00:00+00:00
#
#          payload.pay_date_nb        payload.pay_date_cu payload.qc_nb  \
# 0  2025-05-20 00:00:00+00:00  2025-05-20 00:00:00+00:00           KRW
# 1  2025-04-29 00:00:00+00:00  2025-04-29 00:00:00+00:00           CHF
# 2  2025-04-29 00:00:00+00:00  2025-04-29 00:00:00+00:00           CHF
#
#   payload.qc_cu  ... payload.diffs.pay_date_days_diff  \
# 0           KRW  ...                                0
# 1           CHF  ...                                0
# 2           CHF  ...                                0
#
#   payload.diffs.ex_date_days_diff             payload.different_fields  \
# 0                               0  [net_qc, net_sc, tax_amt, tax_rate]
# 1                               0                            [nominal]
# 2                               0  [gross_qc, net_qc, net_sc, tax_amt]
#
#    payload.cash_impact  classification.reason_code  \
# 0             450050.0         NET_AMOUNT_MISMATCH
# 1              15000.0   NOMINAL_POSITION_MISMATCH
# 2               6200.0           GROSS_QC_MISMATCH
#
#                           classification.explanation  \
# 0  The net amounts in the custody and NBIM record...
# 1  The nominal position differs between the two a...
# 2  The gross amount in the custody record differs...
#
#                         classification.suggested_fix  classification.priority  \
# 0  Review the net amounts reported in both system...                        3
# 1  Review the nominal position entries for both a...                        3
# 2  Investigate the source of the gross amount dis...                        3
#
#         classification.evidence_fields  classification.notes
# 0  [net_qc, net_sc, tax_amt, tax_rate]
# 1                            [nominal]
# 2  [gross_qc, net_qc, net_sc, tax_amt]
#
# [3 rows x 45 columns]
